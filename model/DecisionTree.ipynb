# %%
# Importing required libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
#importing dataset
data = pd.read_csv("/home/cloud/Downloads/adult_train.csv")

# %%
#reading values and number of rows and columns
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#Preprocessing
#As data contain some values in the form of '?' which might affect the classifier performance
#Cleaning data (Strip spaces, replacing '?' with most frequent value)
for d in data.select_dtypes(include=['object']).columns:
    data[d] = data[d].str.strip()

#replacing '?'
data.replace('?', np.nan, inplace=True)

#dropping rows with '?'
data.dropna(inplace=True)

# %%
#Target handling
data.rename(columns={data.columns[-1]: 'target'}, inplace=True)
data['target'] = data['target'].str.replace('.', '', regex=False)

# %%
#Encoding data
l = LabelEncoder()

for d in data.select_dtypes(include=['object']).columns:
    data[d] = l.fit_transform(data[d])

# %%
#Segregating features and target
X = data.drop('target', axis=1)
y = data['target']

# %%
#Train the model
dt = DecisionTreeClassifier(
    criterion='gini',
    max_depth=10,
    random_state=42)

dt.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %%
#saving the model as .pkl
joblib.dump(dt,'DecisionTree.pkl')
# Out:
# ['DecisionTree.pkl']
